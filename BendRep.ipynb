# %%
#importing
import cv2
import mediapipe as mp
import numpy as np
# for draing on my body
mp_drawing= mp.solutions.drawing_utils
# to get the pose estimation model
mp_pose=mp.solutions.pose

# %%
# taking camera input

cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    cv2.imshow("frame",frame)

    if(cv2.waitKey(10) & 0xFF==ord('q')):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#making detection
#turning on the camera
cap=cv2.VideoCapture(0)
#instatiating a pose estimation model with a given accuracy and tracking confidence score
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:



    while cap.isOpened():



        ret,frame=cap.read()

        #making the image RGB so that it can be feede to mediapipe
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        #for less memory consumption
        image.flags.writeable=False


        #the results will have all the poses    
        results=pose.process(image)

        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        #drawing all the pose son the image captured
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        # pose landmarks will have the location of each and every points in our body
        #pose connection has the connections to various points (nose to eye etc)

        cv2.imshow("frame",image)

        if(cv2.waitKey(10) & 0xFF==ord('q')):

            break
    cap.release()
    cv2.destroyAllWindows()

# %%
#detection of joints
#turning on the camera
cap=cv2.VideoCapture(0)
#instatiating a pose estimation model with a given accuracy and tracking confidence score
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:



    while cap.isOpened():



        ret,frame=cap.read()

        #making the image RGB so that it can be feede to mediapipe
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        #for less memory consumption
        image.flags.writeable=False


        #the results will have all the poses    
        results=pose.process(image)

        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        try:
            landmarks=results.pose_landmarks.landmark
            #landmarks will give all the 33 landmarks in our body
            print(landmarks)
        except:
            pass    

        #drawing all the pose son the image captured
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        # pose landmarks will have the location of each and every points in our body
        #pose connection has the connections to various points (nose to eye etc)

        cv2.imshow("frame",image)

        if(cv2.waitKey(10) & 0xFF==ord('q')):

            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [x: 0.5336019992828369
# y: 0.6367782354354858
# z: -0.9801033139228821
# visibility: 0.9999041557312012
# , x: 0.558613657951355
# y: 0.5603674650192261
# z: -0.9362306594848633
# visibility: 0.9998052716255188
# , x: 0.5746690630912781
# y: 0.5583571195602417
# z: -0.9362677335739136
# visibility: 0.9998301267623901
# , x: 0.5904099941253662
# y: 0.5574602484703064
# z: -0.9365562200546265
# visibility: 0.9997870326042175
# , x: 0.5026216506958008
# y: 0.5620156526565552
# z: -0.9381914138793945
# visibility: 0.9997987151145935
# , x: 0.4846009314060211
# y: 0.5606756210327148
# z: -0.9371450543403625
# visibility: 0.999822199344635
# , x: 0.4674158990383148
# y: 0.5605341196060181
# z: -0.9373420476913452
# visibility: 0.9997856020927429
# , x: 0.6179808378219604
# y: 0.5724421739578247
# z: -0.5434956550598145
# visibility: 0.9998002648353577
# , x: 0.4475037455558777
# y: 0.5799562931060791
# z: -0.5339983701705933
# visibility: 0.9998503923416138
# , x: 0.5680716633796692
# ...

# %%
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)


    # this shows each and every landmark in our body
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %%
print(mp_pose.PoseLandmark.LEFT_SHOULDER.value) 
#this provides the the index at which the following joint is present
# Out:
# 11

# %%
# so to eaxtract a particular joint

# we will
#extracting the coordinates of a  particular landmarkk ie. left shoulder from all landmarks
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]

# this gives the coordinates of that shoulder
# Out:
# x: 0.7547747492790222
# y: 0.8342517018318176
# z: -0.20841221511363983
# visibility: 0.9992182850837708

# %%
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]
# Out:
# x: 0.7547747492790222
# y: 0.8342517018318176
# z: -0.20841221511363983
# visibility: 0.9992182850837708

# %%
landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value]
# Out:
# x: 0.8950062990188599
# y: 1.2006222009658813
# z: -0.3053356111049652
# visibility: 0.37626174092292786

# %%
landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value]
# Out:
# x: 0.8973144292831421
# y: 1.51369309425354
# z: -0.5604900121688843
# visibility: 0.37186160683631897

# %%
def calculate_angle(a,b,c):
    a=np.array(a)
    b=np.array(b)
    c=np.array(c)

    radians=np.arctan2(c[1]-b[1],c[0]-b[0])-np.arctan2(a[1]-b[1],a[0]-b[0])
    angle=np.abs(radians*180/np.pi)

    if angle>180.0:
        angle=360-angle
    return angle

# %%
shoulder=[landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#extracting x and y coordinates of a particular landmark
elbow=[landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
wrist=[landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

# %%
print(shoulder)
# Out:
# [0.7296210527420044, 0.881209671497345]

# %%
#angle of joints
#turning on the camera
cap=cv2.VideoCapture(0)
#instatiating a pose estimation model with a given accuracy and tracking confidence score
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:



    while cap.isOpened():



        ret,frame=cap.read()

        #making the image RGB so that it can be feede to mediapipe
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        #for less memory consumption
        image.flags.writeable=False


        #the results will have all the poses    
        results=pose.process(image)

        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        try:
            landmarks=results.pose_landmarks.landmark
            #landmarks will give all the 33 landmarks in our body
            shoulder=[landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            #extracting x and y coordinates of a particular landmark
            elbow=[landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist=[landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle=calculate_angle(shoulder,elbow,wrist)
            #calculating angle for the three landmarks
            cv2.putText(image,str(angle),tuple(np.multiply(elbow,[640,480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,25,255),2,cv2.LINE_AA) 
            # putting the landmark on the video




            print(landmarks)
        except:
            pass    

        #drawing all the pose son the image captured
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        # pose landmarks will have the location of each and every points in our body
        #pose connection has the connections to various points (nose to eye etc)

        cv2.imshow("frame",image)

        if(cv2.waitKey(10) & 0xFF==ord('q')):

            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [x: 0.5261518359184265
# y: 0.6725286245346069
# z: -0.745000422000885
# visibility: 0.9998940229415894
# , x: 0.5506281852722168
# y: 0.591135561466217
# z: -0.7115817070007324
# visibility: 0.9998007416725159
# , x: 0.5699669718742371
# y: 0.5873721837997437
# z: -0.7114023566246033
# visibility: 0.9997972846031189
# , x: 0.5865469574928284
# y: 0.5846208930015564
# z: -0.7119003534317017
# visibility: 0.9998121857643127
# , x: 0.49486881494522095
# y: 0.5988054275512695
# z: -0.6941911578178406
# visibility: 0.9998100399971008
# , x: 0.47671040892601013
# y: 0.5999517440795898
# z: -0.6931446194648743
# visibility: 0.9997963309288025
# , x: 0.4603063464164734
# y: 0.6013824939727783
# z: -0.6934168338775635
# visibility: 0.999804675579071
# , x: 0.6148571968078613
# y: 0.6000950336456299
# z: -0.3809484839439392
# visibility: 0.9998170733451843
# , x: 0.44488048553466797
# y: 0.6228835582733154
# z: -0.2763925790786743
# visibility: 0.9998352527618408
# , x: 0.5682693123817444
# ...

# %%
#curl counter
#turning on the camera
cap=cv2.VideoCapture(0)

count=0
stage=None
#instatiating a pose estimation model with a given accuracy and tracking confidence score
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:



    while cap.isOpened():



        ret,frame=cap.read()

        #making the image RGB so that it can be feede to mediapipe
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        #for less memory consumption
        image.flags.writeable=False


        #the results will have all the poses    
        results=pose.process(image)

        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        try:
            landmarks=results.pose_landmarks.landmark
            #landmarks will give all the 33 landmarks in our body
            shoulder=[landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            #extracting x and y coordinates of a particular landmark
            elbow=[landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist=[landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle=calculate_angle(shoulder,elbow,wrist)
            #calculating angle for the three landmarks
            cv2.putText(image,str(angle),tuple(np.multiply(elbow,[640,480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,25,255),2,cv2.LINE_AA) 
            # putting the landmark on the video

            # countingbends 
            if(angle>160):
                stage="down";
            if angle<30 and stage=="down":
                stage="up"
                count+=1
                print(count)    




            print(landmarks)
        except:
            pass  
        #drawing rectangle at top   
        cv2.rectangle(image,(0,0),(255,73),(245,117,16),-1)

        #putting the counter on to the rectnagle
        cv2.putText(image,'REPS',(15,12),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,0),1,cv2.LINE_AA)   
        cv2.putText(image,str(count),(10,60),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1,cv2.LINE_AA)   

        #drawing all the pose son the image captured
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        # pose landmarks will have the location of each and every points in our body
        #pose connection has the connections to various points (nose to eye etc)

        cv2.imshow("frame",image)

        if(cv2.waitKey(10) & 0xFF==ord('q')):

            break
    cap.release()
    cv2.destroyAllWindows()

# %%
import threading as th
import time

def delay(n):
    global my_timer
    my_timer=0
    while(n):
        time.sleep(1)
        print("delay ",my_timer)
        my_timer+=1
        n-=1

# %%
#Legbend counter
#turning on the camera
import time
import threading as th
# cap=cv2.VideoCapture("C:/Users/Anirudh/OneDrive/Desktop/KneeBendVideo.mp4")
cap=cv2.VideoCapture("C:/Users/Anirudh/OneDrive/Desktop/KneeBendVideo.mp4")
th1=None
count=0
stage=None
#instatiating a pose estimation model with a given accuracy and tracking confidence score
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:



    while cap.isOpened():



        ret,frame=cap.read()

        #making the image RGB so that it can be feede to mediapipe
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        #for less memory consumption
        image.flags.writeable=False


        #the results will have all the poses    
        results=pose.process(image)

        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        try:
            landmarks=results.pose_landmarks.landmark
            #landmarks will give all the 33 landmarks in our body
            left_hip=[landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            #extracting x and y coordinates of a particular landmark
            left_knee=[landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            left_ankle=[landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]

            angle=calculate_angle(left_hip,left_knee,left_ankle)
            #calculating angle for the three landmarks
            cv2.putText(image,str(angle),tuple(np.multiply(left_knee,[640,480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX,0.75,(255,25,255),2,cv2.LINE_AA) 
            # putting the landmark on the video

            # countingcurls 
            seconds=0

            if(angle>141):
                stage="down"
                if(th1.is_alive()):
                    my_timer=0

                    cv2.putText(image,'Keep your knee bent',(30,150),cv2.FONT_HERSHEY_SIMPLEX,0.75,(255,0,255),2,cv2.LINE_AA)
                    
                
            if angle<140 and stage=="down":
                n=8
                if(th1==None or not th1.is_alive()):
                    th1=th.Thread(target=delay, args=(n,))
                    th1.start()
                cv2.putText(image,str(my_timer),(30,100),cv2.FONT_HERSHEY_SIMPLEX,0.75,(255,255,0),2,cv2.LINE_AA)
                if(my_timer>=n-1):
                    th1.join()
                    stage="up"
                    count+=1

                
                    
            # print(landmarks)
        except:
            pass  
        #drawing rectangle at top   
        cv2.rectangle(image,(0,0),(255,73),(245,117,16),-1)

        #putting the counter on to the rectnagle
        cv2.putText(image,'REPS',(15,12),cv2.FONT_HERSHEY_SIMPLEX,0.75,(0,0,0),2,cv2.LINE_AA)   
        cv2.putText(image,str(count),(10,60),cv2.FONT_HERSHEY_SIMPLEX,0.75,(255,255,255),2,cv2.LINE_AA)   

        #drawing all the pose son the image captured
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        # pose landmarks will have the location of each and every points in our body
        #pose connection has the connections to various points (nose to eye etc)

        cv2.imshow("frame",image)

        if(cv2.waitKey(10) & 0xFF==ord('q')):

            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# delay  0
# delay  1
# delay  2
# delay  3
# delay  4
# delay  5
# delay  6
# delay  7
# delay  0
# delay  1
# delay  2
# delay  3
# delay  4
# delay  5
# delay  6
# delay  7
# delay  0
# delay  1
# delay  2
# delay  3
# delay  4
# delay  5
# delay  6
# delay  7
# delay  0
# delay  1
# delay  2
# delay  3
# delay  4
# delay  5
# delay  6
# delay  7
# delay  0
# delay  1
# delay  2
# delay  3
# delay  4
# delay  5
# delay  6
# delay  7
# delay  0
# delay  0
# delay  0
# delay  1
# delay  0
# delay  0
# delay  0
# delay  0
# delay  0
# delay  1
# delay  2
# delay  0
# delay  0
# delay  0
# delay  0
# delay  0

# %%
import threading as th  
## Defining a method  
def timer():  
   if(angle<140):
      S = th.Timer(5.0, angle)
      S.start()
      count=count+1
   if(angle>140):
      print("Keep your knee bent")
      S.cancel()

# %%
import time
import threading as th
global my_timer
def delay(n):
    my_timer=0

    for i in range(n):
        time.sleep(1)
        my_timer=my_timer+1

    print("time up")

# %%
import threading as th

def delay(n):
    while(n):


        time.sleep(1)
        print("delay")
        n=n-1
